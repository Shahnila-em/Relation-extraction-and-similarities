# %%
import numpy as np 
import pandas as pd
from tqdm import tqdm_notebook as tqdm
from pyecharts import options as opts
from pyecharts.charts import Graph
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset,TensorDataset,DataLoader
from keras.preprocessing import sequence
from transformers import BertTokenizer, BertForSequenceClassification

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings('ignore')

# %%
marked_sentence_df = pd.read_csv('C:/Users/HP/Desktop/final499b/CSE499B/COVID-19 knowledge graph/marked_sentence.csv')

# %%
marked_sentence_df.sample(5)
# Out:
#              start_entity           end_entity start_entity_type  \
# 10658                  C2                  CD2              Gene
# 31705                AOC3                 CD16              Gene
# 16300              Eczema            Infection           Disease
# 21869                CCL2                 GLS2              Gene
# 15804  Rhinitis, Allergic  Wounds and Injuries           Disease
#
#       end_entity_type                                    marked_sentence
# 10658            Gene  Further clonal analysis of this patient indica...
# 31705            Gene  CONCLUSIONS: Our data suggest that end_entity ...
# 16300         Disease  1 Million South Korean Health-Care Records Gwa...
# 21869            Gene  PHF, PTGDR and end_entity could significantly ...
# 15804         Disease  Pieters A245 How to Define Chronic Cough: Base...

# %%
def Build_graph(df,relation=False,repulsion=40,title='COVID-19 knowledge graph',labelShow=False):
    entity_type_dic = dict(df.drop_duplicates(['start_entity']).set_index(['start_entity'])['start_entity_type'])
    entity_type_dic.update(dict(df.drop_duplicates(['end_entity']).set_index(['end_entity'])['end_entity_type']))
    color = {'Disease':'#FF7F50','Gene':'#48D1CC','Chemical':'#B3EE3A'}
    cate =  {'Disease':0,'Gene':1,'Chemical':2}
    categories = [{'name':'Disease','itemStyle': {'normal': {'color': color['Disease']}}},{'name':'Gene','itemStyle': {'normal': {'color': color['Gene']}}},{'name':'Chemical','itemStyle': {'normal': {'color': color['Chemical']}}}]
    nodes = []
    for entity in list(set(df['start_entity'])|set(df['end_entity'])):
        nodes.append({'name': entity, 'symbolSize': max(10,np.log1p(df.loc[(df['start_entity']==entity)|(df['end_entity']==entity)].shape[0])*10//1),
                     'category':cate[entity_type_dic[entity]]})
    links = []
    for i in df.index:
        if not relation:
            links.append({'source': df.loc[i,'start_entity'], 'target': df.loc[i,'end_entity']})
        else:
            links.append({'source': df.loc[i,'start_entity'], 'target': df.loc[i,'end_entity'], 'value':df.loc[i,'pred']})
    g = (
        Graph()
        .add('', nodes, links,categories, repulsion=repulsion,label_opts=opts.LabelOpts(is_show=labelShow))
        .set_global_opts(title_opts=opts.TitleOpts(title=title),legend_opts=opts.LegendOpts(orient='vertical', pos_left='2%', pos_top='40%',legend_icon='circle'))
        .render_notebook()
        )
    return g

# %%
g = Build_graph(marked_sentence_df.sample(100),title='subsample of  graph')
g
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e517cf282ce847af9d8ac9e8ed1072cf" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e517cf282ce847af9d8ac9e8ed1072cf = echarts.init(
#                     document.getElementById('e517cf282ce847af9d8ac9e8ed1072cf'), 'white', {renderer: 'canvas'});
#                 var option_e517cf282ce847af9d8ac9e8ed1072cf = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "graph",
#             "layout": "force",
#             "symbolSize": 10,
#             "circular": {
#                 "rotateLabel": false
#             },
#             "force": {
#                 "repulsion": 40,
#                 "edgeLength": 50,
#                 "gravity": 0.2
#             },
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "roam": true,
#             "draggable": false,
#             "focusNodeAdjacency": true,
#             "data": [
#                 {
#                     "name": "A20",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "MERS",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "CD8A",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "PYCARD",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "PLP1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "SOCS1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "RTCB",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "Skin Diseases",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "ROS1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "E3",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "Eczema",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Wounds and Injuries",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "SOAT1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "KRT8",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "Familial paroxysmal dystonia",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "CAP",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "HPRT1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "PML",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "Van der Woude syndrome",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "EGF",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "PSME3",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "IRF3",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "IFNA1",
#                     "symbolSize": 13.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "GPA33",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "CEA",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "RGCC",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "Metabolic Syndrome X",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "FBLN7",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "Cough",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "creatine kinase",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "S2",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "Marek Disease",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "COPS5",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "CTSL",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "Translocation, Genetic",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "DLL1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "ACE",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "PLpro",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "Carcinoma, Hepatocellular",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "CD16",
#                     "symbolSize": 10,
#                     "category": 1

# %%
class Args:
    task_type = 'chemical-disease'
    max_seq_len = 64
    bs = 64

class Conf:
    # some information can be found in:
    # Percha B, Altman R B. A global network of biomedical relationships derived from text[J]. Bioinformatics, 2018, 34(15): 2614-2624.
    relation_type = {'chemical-disease':['T', 'C', 'Sa', 'Pr', 'Pa', 'J'],
                     'disease-chemical':['Mp'],
                     'chemical-gene':['A+', 'A-', 'B', 'E+', 'E-', 'E', 'N'],
                     'gene-chemical':['O', 'K', 'Z'],
                     'gene-disease':['U', 'Ud', 'D', 'J', 'Te', 'Y', 'G'],
                     'disease-gene':['Md', 'X', 'L'],
                     'gene-gene':['B', 'W', 'V+', 'E+', 'E', 'I', 'H', 'Rg', 'Q'],
                     }

args = Args()
conf = Conf()
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %%
# load pretrained Bert model
def Bert_model(taskType,bertPath):
    label_df = pd.read_csv('C:/Users/HP/Desktop/final499b/CSE499B/COVID-19 knowledge graph/%s_label.csv'%taskType)
    tokenizer = BertTokenizer.from_pretrained(bertPath,do_lower_case=False)
    model = BertForSequenceClassification.from_pretrained(bertPath, num_labels=label_df['label'].nunique())
    return label_df,tokenizer,model

# bulid data loader
def Data_loader(x,y=None,bs=128,shuffle=False,numWorkers=0):
    if y is not None:
        data = TensorDataset(x,y)
    else:
        data = TensorDataset(x)
    data_loader = DataLoader(dataset=data,batch_size=bs,shuffle=shuffle,num_workers=numWorkers)
    return data_loader

def Prepare_predict_data(tokenizer,bs):
    marked_sentences = marked_sentence_df.loc[(marked_sentence_df['start_entity_type'].apply(lambda x:x.lower())==args.task_type.split('-')[0])&\
                                              (marked_sentence_df['end_entity_type'].apply(lambda x:x.lower())==args.task_type.split('-')[1]),'marked_sentence']
    # convert tokens to ids
    ids = marked_sentences.apply(lambda x:tokenizer.convert_tokens_to_ids(tokenizer.tokenize(x))).tolist()
    # padding ids
    ids = sequence.pad_sequences(ids,args.max_seq_len, truncating='post', padding='post')
    # we cannot confirm order of entities, so predict two possibilities
    reverse_marked_sentences = marked_sentence_df.loc[(marked_sentence_df['start_entity_type'].apply(lambda x:x.lower())==args.task_type.split('-')[0])&\
                                              (marked_sentence_df['end_entity_type'].apply(lambda x:x.lower())==args.task_type.split('-')[1]),'marked_sentence']\
                                              .apply(lambda x:x.replace('start_entity','init_start_entity').replace('end_entity','start_entity').replace('init_start_entity','end_entity'))
    reverse_ids = reverse_marked_sentences.apply(lambda x:tokenizer.convert_tokens_to_ids(tokenizer.tokenize(x))).tolist()
    reverse_ids = sequence.pad_sequences(reverse_ids,args.max_seq_len, truncating='post', padding='post')
    predict_data_loader = Data_loader(torch.LongTensor(ids),torch.LongTensor(reverse_ids),bs=bs)
    return marked_sentences.values,predict_data_loader

def Predict():
    reverse_task_type = args.task_type.split('-')[1] + '-' + args.task_type.split('-')[0]
    def Filter(x):
        if x['init_pred'] in conf.relation_type[args.task_type]:
            if x['reverse_pred'] not in conf.relation_type[reverse_task_type]:
                # init_pred is a correct relation but reverse_pred not
                return 'init_pred'
            else:
                # init_pred and reverse_pred both are correct relations
                if x['init_pred_prob'] >= x['reverse_pred_prob']:
                    # init_pred_prob greater than or equal to reverse_pred_prob
                    return 'init_pred'
                else:
                    return 'reverse_pred'
        else:
            if x['reverse_pred'] not in conf.relation_type[reverse_task_type]:
                # init_pred and reverse_pred both are uncorrect relations
                return 'uncorrect'
            else:
                # reverse_pred is a correct relation but init_pred not
                return 'reverse_pred'
    label_df,tokenizer,model = Bert_model(args.task_type,'C:/Users/HP/Desktop/final499b/CSE499B/COVID-19 knowledge graph/%s/'%args.task_type)
    marked_sentences,predict_data_loader = Prepare_predict_data(tokenizer,args.bs)
    model = model.to(device)
    preds = []
    preds_prob = []
    reverse_preds = []
    reverse_preds_prob = []
    for data in tqdm(predict_data_loader):
        ids,reverse_ids = [t.to(device) for t in data]
        outputs = model(input_ids=ids)
        logits = outputs[0]
        pred_prob, pred = torch.max(F.softmax(logits.data,1), 1)
        preds.extend(list(pred.cpu().detach().numpy()))
        preds_prob.extend(list(pred_prob.cpu().detach().numpy()))
        reverse_outputs = model(input_ids=reverse_ids)
        reverse_logits = reverse_outputs[0]
        reverse_pred_prob, reverse_pred = torch.max(F.softmax(reverse_logits.data,1), 1)
        reverse_preds.extend(list(reverse_pred.cpu().detach().numpy()))
        reverse_preds_prob.extend(list(reverse_pred_prob.cpu().detach().numpy()))

    pred_df = pd.DataFrame({'marked_sentence':marked_sentences,'init_pred':preds,'init_pred_prob':preds_prob,'reverse_pred':reverse_preds,'reverse_pred_prob':reverse_preds_prob})
    # map label(0, 1, 2...) to raw label(T, C, Sa...) 
    pred_df['init_pred'] = pred_df['init_pred'].replace(dict(label_df.set_index(['label'])['label_raw']))
    pred_df['reverse_pred'] = pred_df['reverse_pred'].replace(dict(label_df.set_index(['label'])['label_raw']))
    # judge the order of a pair of entities
    pred_df['filter'] = pred_df.apply(lambda x:Filter(x), axis=1)
    pred_df['pred'] = pred_df['init_pred']
    pred_df['pred_prob'] = pred_df['init_pred_prob']
    pred_df.loc[pred_df['filter']=='reverse_pred','pred'] = pred_df.loc[pred_df['filter']=='reverse_pred','reverse_pred']
    pred_df.loc[pred_df['filter']=='reverse_pred','pred_prob'] = pred_df.loc[pred_df['filter']=='reverse_pred','reverse_pred_prob']
    pred_df = pred_df.loc[pred_df['filter']!='uncorrect']
    pred_df = marked_sentence_df.merge(pred_df,how='inner',on='marked_sentence')
    pred_df['init_start_entity'] = pred_df['start_entity']
    pred_df['init_start_entity_type'] = pred_df['start_entity_type']
    pred_df.loc[pred_df['filter']=='reverse_pred','start_entity'] = pred_df.loc[pred_df['filter']=='reverse_pred','end_entity']
    pred_df.loc[pred_df['filter']=='reverse_pred','start_entity_type'] = pred_df.loc[pred_df['filter']=='reverse_pred','end_entity_type']
    pred_df.loc[pred_df['filter']=='reverse_pred','end_entity'] = pred_df.loc[pred_df['filter']=='reverse_pred','init_start_entity']
    pred_df.loc[pred_df['filter']=='reverse_pred','end_entity_type'] = pred_df.loc[pred_df['filter']=='reverse_pred','init_start_entity_type']
    pred_df.drop(['init_start_entity','init_start_entity_type'],axis=1,inplace=True)
    torch.cuda.empty_cache()
    return label_df,pred_df

# %%
# chemical-disease relation prediction
args.task_type = 'chemical-disease'
c_d_label_df,c_d_pred_df = Predict()
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
# chemical-disease relation theme
c_d_label_df
# Out:
#   label_raw  label                                    theme
# 0         C      0      Inhibits cell growth (esp. cancers)
# 1         J      1                     Role in pathogenesis
# 2        Mp      2                 Biomarkers (progression)
# 3        Pa      3                      Alleviates, reduces
# 4        Pr      4                     Prevents, suppresses
# 5        Sa      5                Side effect/adverse event
# 6         T      6  Treatment/therapy (incl. investigatory)

# %%
# chemical-disease classification results
c_d_pred_df.sample(5)
# Out:
#       start_entity                  end_entity start_entity_type  \
# 693     Omalizumab        Egg Hypersensitivity          Chemical
# 204  Chlorhexidine          Rhinitis, Allergic          Chemical
# 390    Anaphylaxis                Cyclosporine           Disease
# 502      Infection  Intravenous Immunoglobulin           Disease
# 190       Rhinitis                     Toluene           Disease
#
#     end_entity_type                                    marked_sentence  \
# 693         Disease  Ehlayel, Abdul Bari Bener A607 Strong Associat...
# 204         Disease  Pieters A151 Clinical significance between the...
# 390        Chemical  1 Million South Korean Health-Care Records Gwa...
# 502        Chemical  Akio Tanaka, Satoshi Morioke, Yukihiro Ohya, N...
# 190        Chemical  Leung, Ka Hou Chu A67 The relationship between...
#
#     init_pred  init_pred_prob reverse_pred  reverse_pred_prob        filter  \
# 693         T        0.580928            T           0.580928     init_pred
# 204        Sa        0.997375           Sa           0.997375     init_pred
# 390        Mp        0.992673           Mp           0.992673  reverse_pred
# 502        Mp        0.586789           Mp           0.586789  reverse_pred
# 190        Mp        0.913594           Mp           0.913594  reverse_pred
#
#     pred  pred_prob
# 693    T   0.580928
# 204   Sa   0.997375
# 390   Mp   0.992673
# 502   Mp   0.586789
# 190   Mp   0.913594

# %%
# chemical-gene relation prediction
args.task_type = 'chemical-gene'
c_g_label_df,c_g_pred_df = Predict()
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]

# %%
# chemical-gene relation theme
c_g_label_df
# Out:
#   label_raw  label                                    theme
# 0        A+      0                      Agonism, activation
# 1        A-      1                     Antagonism, blocking
# 2         B      2         Binding, ligand (esp. receptors)
# 3         E      3  Affects expression/production (neutral)
# 4        E-      4          Decreases expression/production
# 5         K      5             Metabolism, pharmacokinetics
# 6         N      6                                 Inhibits
# 7         O      7                      Transport, channels
# 8         Z      8                          Enzyme activity

# %%
# chemical-gene classification results
c_g_pred_df.sample(5)
# Out:
#                start_entity                end_entity start_entity_type  \
# 329             ventilation  alanine aminotransferase          Chemical
# 371             Oseltamivir                        RD          Chemical
# 167                 Toluene                        AR          Chemical
# 324                   rhMBL                       MBL          Chemical
# 320  mesenchymal stem cells                      MTOR          Chemical
#
#     end_entity_type                                    marked_sentence  \
# 329            Gene  Demographics, rate of mechanical start_entity ...
# 371            Gene  start_entity increased the risk of headaches w...
# 167            Gene  Leung, Ka Hou Chu A67 The relationship between...
# 324            Gene  Although recombinant human end_entity start_en...
# 320            Gene  In addition, many intracellular signaling path...
#
#     init_pred  init_pred_prob reverse_pred  reverse_pred_prob     filter pred  \
# 329         E        0.960856            E           0.989686  init_pred    E
# 371        E-        0.987741            E           0.813697  init_pred   E-
# 167         B        0.729219            B           0.729219  init_pred    B
# 324         N        0.626527            E           0.955956  init_pred    N
# 320         N        0.755158            N           0.755158  init_pred    N
#
#      pred_prob
# 329   0.960856
# 371   0.987741
# 167   0.729219
# 324   0.626527
# 320   0.755158

# %%
# gene-disease relation prediction
args.task_type = 'gene-disease'
g_d_label_df,g_d_pred_df = Predict()
# Out:
#   0%|          | 0/142 [00:00<?, ?it/s]

# %%
# gene-disease relation theme
g_d_label_df
# Out:
#   label_raw  label                                  theme
# 0         D      0                           Drug targets
# 1         G      1                   Promotes progression
# 2         J      2                   Role in pathogenesis
# 3         L      3  Improper regulation linked to disease
# 4        Md      4                Biomarkers (diagnostic)
# 5        Te      5            Possible therapeutic effect
# 6         U      6                       Causal mutations
# 7        Ud      7        Mutations affect disease course
# 8         X      8              Overexpression in disease
# 9         Y      9               Polymorphisms alter risk

# %%
# gene-disease classification results
g_d_pred_df.sample(5)
# Out:
#      start_entity               end_entity start_entity_type end_entity_type  \
# 3924        MAPK8       Rhinitis, Allergic              Gene         Disease
# 6998         NCR1                 Melanoma              Gene         Disease
# 2651       ADAM17     Sleep Wake Disorders              Gene         Disease
# 4699          CRP  Porphyria Cutanea Tarda              Gene         Disease
# 517         IKBKG                 diarrhea              Gene         Disease
#
#                                         marked_sentence init_pred  \
# 3924  Ehlayel, Abdul Bari Bener A607 Strong Associat...         J
# 6998  nnAbbreviationsAHR, airway hyperresponsiveness...         J
# 2651  Leung, Ka Hou Chu A67 The relationship between...        Te
# 4699  The peripheral blood white blood cell WBC coun...         J
# 517   The PDCoV nsp5 cleavage site in the start_enti...         U
#
#       init_pred_prob reverse_pred  reverse_pred_prob     filter pred  \
# 3924        0.737792            J           0.737792  init_pred    J
# 6998        0.999631            J           0.999631  init_pred    J
# 2651        0.736633           Te           0.736633  init_pred   Te
# 4699        0.999971            J           0.999978  init_pred    J
# 517         0.999780            U           0.999422  init_pred    U
#
#       pred_prob
# 3924   0.737792
# 6998   0.999631
# 2651   0.736633
# 4699   0.999971
# 517    0.999780

# %%
# gene-gene relation prediction
args.task_type = 'gene-gene'
g_g_label_df,g_g_pred_df = Predict()
# Out:
#   0%|          | 0/340 [00:00<?, ?it/s]

# %%
# gene-gene relation theme
g_g_label_df
# Out:
#   label_raw  label                                    theme
# 0         B      0         Binding, ligand (esp. receptors)
# 1         E      1  Affects expression/production (neutral)
# 2        E+      2          Increases expression/production
# 3         H      3                  Same protein or complex
# 4         I      4                        Signaling pathway
# 5         Q      5            Production by cell population
# 6        Rg      6                               Regulation
# 7        V+      7                    Activates, stimulates
# 8         W      8                        Enhances response

# %%
# gene-gene classification results
g_g_pred_df.sample(5)
# Out:
#       start_entity end_entity start_entity_type end_entity_type  \
# 8514         IFNA1        MX1              Gene            Gene
# 2083           p38      MAPK8              Gene            Gene
# 20807      d-dimer     NDUFB6              Gene            Gene
# 3955        NPIPB3     NPIPA1              Gene            Gene
# 6989          CCL5       CCR1              Gene            Gene
#
#                                          marked_sentence init_pred  \
# 8514   CONCLUSIONS: This study has identified various...        E+
# 2083   We specifically identified end_entity and star...        Rg
# 20807  Multivariable regression showed increasing odd...        V+
# 3955   Results The highest affinity clone to ORF6 dis...         H
# 6989   We also evaluated protein levels of CCL2, end_...         B
#
#        init_pred_prob reverse_pred  reverse_pred_prob        filter pred  \
# 8514         0.998990           E+           0.989102     init_pred   E+
# 2083         0.541112           Rg           0.586573  reverse_pred   Rg
# 20807        0.964366           V+           0.979759  reverse_pred   V+
# 3955         0.978994            H           0.993285  reverse_pred    H
# 6989         0.568204            I           0.312748     init_pred    B
#
#        pred_prob
# 8514    0.998990
# 2083    0.586573
# 20807   0.979759
# 3955    0.993285
# 6989    0.568204

# %%
# chemicl-COVID-19 relations
g = Build_graph(c_d_pred_df.loc[(c_d_pred_df['start_entity']=='COVID-19')|(c_d_pred_df['end_entity']=='COVID-19')],relation=True,repulsion=800,title='chemical-COVID-19 knowledge graph',labelShow=True)
g
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b9a39d66758041599013155ebb7e6f32" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b9a39d66758041599013155ebb7e6f32 = echarts.init(
#                     document.getElementById('b9a39d66758041599013155ebb7e6f32'), 'white', {renderer: 'canvas'});
#                 var option_b9a39d66758041599013155ebb7e6f32 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "graph",
#             "layout": "force",
#             "symbolSize": 10,
#             "circular": {
#                 "rotateLabel": false
#             },
#             "force": {
#                 "repulsion": 800,
#                 "edgeLength": 50,
#                 "gravity": 0.2
#             },
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "roam": true,
#             "draggable": false,
#             "focusNodeAdjacency": true,
#             "data": [
#                 {
#                     "name": "SSYA10-001",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": "remdesivir",
#                     "symbolSize": 23.0,
#                     "category": 2
#                 },
#                 {
#                     "name": " oxygen therapy ",
#                     "symbolSize": 13.0,
#                     "category": 2
#                 },
#                 {
#                     "name": "Vitamin C",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": "ventilation",
#                     "symbolSize": 34.0,
#                     "category": 2
#                 },
#                 {
#                     "name": "Hydroxychloroquine",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": "PX-12",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": "mesenchymal stem cells",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": "Doxycycline",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": "Daptomycin",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": "membrane oxygenation",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": "Oseltamivir",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": "oseltamivir",
#                     "symbolSize": 16.0,
#                     "category": 2
#                 },
#                 {
#                     "name": "Chloroquine",
#                     "symbolSize": 13.0,
#                     "category": 2
#                 },
#                 {
#                     "name": "Toluene",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": "COVID-19",
#                     "symbolSize": 43.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "Zinc",
#                     "symbolSize": 13.0,
#                     "category": 2
#                 },
#                 {
#                     "name": "Amantadine",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": "Hexamethylene amiloride",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": "glucocorticoids",
#                     "symbolSize": 13.0,
#                     "category": 2
#                 },
#                 {
#                     "name": "Ganciclovir",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": "Lopinavir",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": "Nitazoxanide",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": "Lopinavir/Ritonavir",
#                     "symbolSize": 10,
#                     "category": 2
#                 }
#             ],
#             "categories": [
#                 {
#                     "name": "Disease",
#                     "itemStyle": {
#                         "normal": {
#                             "color": "#FF7F50"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Gene",
#                     "itemStyle": {
#                         "normal": {
#                             "color": "#48D1CC"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Chemical",
#                     "itemStyle": {
#                         "normal": {
#                             "color": "#B3EE3A"
#                         }
#                     }
#                 }
#             ],
#             "edgeLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "edgeSymbol": [
#                 null,
#                 null
#             ],
#             "edgeSymbolSize": 10,
#             "links": [
#                 {
#                     "source": "Daptomycin",
#                     "target": "COVID-19",
#                     "value": "T"
#                 },
#                 {
#                     "source": "ventilation",
#                     "target": "COVID-19",
#                     "value": "T"
#                 },
#                 {
#                     "source": "Nitazoxanide",
#                     "target": "COVID-19",
#                     "value": "C"
#                 },
#                 {
#                     "source": "ventilation",
#                     "target": "COVID-19",
#                     "value": "Sa"
#                 },
#                 {
#                     "source": "oseltamivir",
#                     "target": "COVID-19",
#                     "value": "T"
#                 },
#                 {
#                     "source": "ventilation",
#                     "target": "COVID-19",
#                     "value": "Pr"
#                 },
#                 {
#                     "source": "Ganciclovir",
#                     "target": "COVID-19",
#                     "value": "T"
#                 },
#                 {
#                     "source": "ventilation",
#                     "tar

# %%
# gene-COVID-19 relations
g = Build_graph(g_d_pred_df.loc[(g_d_pred_df['start_entity']=='COVID-19')|(g_d_pred_df['end_entity']=='COVID-19')],relation=True,repulsion=60,title='gene-COVID-19 knowledge graph',labelShow=False)
g
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ebe301dba1fe40b78c1a5d5d181e506e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ebe301dba1fe40b78c1a5d5d181e506e = echarts.init(
#                     document.getElementById('ebe301dba1fe40b78c1a5d5d181e506e'), 'white', {renderer: 'canvas'});
#                 var option_ebe301dba1fe40b78c1a5d5d181e506e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "graph",
#             "layout": "force",
#             "symbolSize": 10,
#             "circular": {
#                 "rotateLabel": false
#             },
#             "force": {
#                 "repulsion": 60,
#                 "edgeLength": 50,
#                 "gravity": 0.2
#             },
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "roam": true,
#             "draggable": false,
#             "focusNodeAdjacency": true,
#             "data": [
#                 {
#                     "name": "PYCARD",
#                     "symbolSize": 16.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "MTB",
#                     "symbolSize": 20.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "CD8A",
#                     "symbolSize": 30.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "TRPV1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "FBL",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "ADAM10",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "SPHK2",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "PDCD1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "CAT",
#                     "symbolSize": 13.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "P1",
#                     "symbolSize": 13.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "CPA1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "CAP",
#                     "symbolSize": 48.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "B1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "MB",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "EGF",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "ZNF398",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "CRF",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "TLR2",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "PTB",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "aspartate aminotransferase",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "CEA",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "SPR",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "PPA1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "VDR",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "ADI1",
#                     "symbolSize": 16.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "IFNAR1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "IFITM1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "MRLN",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "MAX",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "J2",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "A1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "TLR4",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "EDEM1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "CCL7",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "IL15",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "LY6E",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "IL17A",
#                     "symbolSize": 16.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "BECN1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "IL4",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "UCN",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "\u00a0C-reactive protein",
#                     "symbolSize": 2

# %%
# gene-COVID-19 relations
g = Build_graph(marked_sentence_df.loc[(marked_sentence_df['start_entity']=='COVID-19')&(marked_sentence_df['end_entity_type']=='Disease')|(marked_sentence_df['start_entity_type']=='Disease')&(marked_sentence_df['end_entity']=='COVID-19')],relation=False,repulsion=60,title='disease-COVID-19  graph',labelShow=False)
g
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="72e342a30a9c4b799d52ac8328ec085c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_72e342a30a9c4b799d52ac8328ec085c = echarts.init(
#                     document.getElementById('72e342a30a9c4b799d52ac8328ec085c'), 'white', {renderer: 'canvas'});
#                 var option_72e342a30a9c4b799d52ac8328ec085c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "graph",
#             "layout": "force",
#             "symbolSize": 10,
#             "circular": {
#                 "rotateLabel": false
#             },
#             "force": {
#                 "repulsion": 60,
#                 "edgeLength": 50,
#                 "gravity": 0.2
#             },
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "roam": true,
#             "draggable": false,
#             "focusNodeAdjacency": true,
#             "data": [
#                 {
#                     "name": "Vasculopathy, Retinal, With Cerebral Leukodystrophy",
#                     "symbolSize": 13.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "MERS",
#                     "symbolSize": 55.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "Sprains and Strains",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Leukemia, Myelogenous, Chronic, BCR-ABL Positive",
#                     "symbolSize": 23.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "Porphyria Cutanea Tarda",
#                     "symbolSize": 23.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "Hantavirus Pulmonary Syndrome",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Bulimia Nervosa",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "heart rate",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Classical Swine Fever",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Noonan Syndrome 6",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Nail-Patella Syndrome",
#                     "symbolSize": 13.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "Retinitis Pigmentosa 2",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Inflammation",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Wounds and Injuries",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Netherton Syndrome",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Enteritis",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Achondroplasia",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Van der Woude syndrome",
#                     "symbolSize": 17.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "Measles",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Chromosome 3-Linked Frontotemporal Dementia",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Hepatolenticular Degeneration",
#                     "symbolSize": 20.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "Cough",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Systemic carnitine deficiency",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Cryptogenic Organizing Pneumonia",
#                     "symbolSize": 16.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "Dengue",
#                     "symbolSize": 23.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "Carcinoma, Hepatocellular",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Encephalitis, Japanese",
#                     "symbolSize": 16.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "PSS",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Neural Tube Defects",
#                     "symbolSize": 16.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "Immunologic Deficiency Syndromes",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Polyps",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Ataxia Telangiectasia",
#                     "symbolSize": 13.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "Noonan Syndrome 4",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "lung transplantation",
#                     "symbolSize": 17.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "Sleep Wake Disorders",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Pigmentary Disorder, Reticulate, with Systemic Manifestations",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Pseudorabies",

# %%
# merge all relation prediction and save results
cols = ['start_entity','end_entity','start_entity_type','end_entity_type','marked_sentence','pred','pred_prob']
relation_df = pd.concat([c_d_pred_df[cols],c_g_pred_df[cols],g_d_pred_df[cols],g_g_pred_df[cols]]).append(marked_sentence_df.loc[(marked_sentence_df['start_entity_type'].isin(['Chemical','Disease'])&(marked_sentence_df['start_entity_type']==marked_sentence_df['end_entity_type']))]).reset_index(drop=True)
relation_df.loc[(relation_df['pred'].isna())&(relation_df['start_entity_type']=='Chemical'),'pred'] = 'CC'
relation_df.loc[(relation_df['pred'].isna())&(relation_df['start_entity_type']=='Disease'),'pred'] = 'DD'
relation_df = relation_df[cols]
relation_df.to_csv('relation.csv',index=False)

# %%
relation_df
# Out:
#                             start_entity                         end_entity  \
# 0              keyhole limpet hemocyanin      Lupus Erythematosus, Systemic
# 1                                Cocaine             Incontinentia Pigmenti
# 2                             Daptomycin                           COVID-19
# 3                                   Zinc                           diarrhea
# 4                                   Zinc   Glycogen Storage Disease Type II
# ...                                  ...                                ...
# 39577             Coronavirus Infections  Severe Acute Respiratory Syndrome
# 39578             Coronavirus Infections                           Syndrome
# 39579                               MERS  Severe Acute Respiratory Syndrome
# 39580                               MERS                           Syndrome
# 39581  Severe Acute Respiratory Syndrome                           Syndrome
#
#       start_entity_type end_entity_type  \
# 0              Chemical         Disease
# 1              Chemical         Disease
# 2              Chemical         Disease
# 3              Chemical         Disease
# 4              Chemical         Disease
# ...                 ...             ...
# 39577           Disease         Disease
# 39578           Disease         Disease
# 39579           Disease         Disease
# 39580           Disease         Disease
# 39581           Disease         Disease
#
#                                          marked_sentence pred  pred_prob
# 0      Middle-aged female identical twins, one of who...   Pa   0.969854
# 1      start_entity 10 mgkg, administered intraperito...   Pa   0.832488
# 2      start_entity is not indicated for end_entity, ...    T   0.999757
# 3      start_entity is being used for the treatment o...   Pa   0.769982
# 4      start_entity was effective in decreasing the i...   Pa   0.423437
# ...                                                  ...  ...        ...
# 39577  In a recent review on the persistence of human...   DD        NaN
# 39578  In a recent review on the persistence of human...   DD        NaN
# 39579  In a recent review on the persistence of human...   DD        NaN
# 39580  In a recent review on the persistence of human...   DD        NaN
# 39581  In a recent review on the persistence of human...   DD        NaN
#
# [39582 rows x 7 columns]

# %%
# subsample of knowledge graph
g = Build_graph(relation_df.sample(1000),relation=True,repulsion=15,title='subsample of COVID-19 knowledge graph',labelShow=False)
g
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="667b1881645344e7b290a35fcd70581e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_667b1881645344e7b290a35fcd70581e = echarts.init(
#                     document.getElementById('667b1881645344e7b290a35fcd70581e'), 'white', {renderer: 'canvas'});
#                 var option_667b1881645344e7b290a35fcd70581e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "graph",
#             "layout": "force",
#             "symbolSize": 10,
#             "circular": {
#                 "rotateLabel": false
#             },
#             "force": {
#                 "repulsion": 15,
#                 "edgeLength": 50,
#                 "gravity": 0.2
#             },
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "roam": true,
#             "draggable": false,
#             "focusNodeAdjacency": true,
#             "data": [
#                 {
#                     "name": "LGALS3BP",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "IGKV6-21",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "DSG3",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "P1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "CAP",
#                     "symbolSize": 25.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "PML",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "CCR9",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "Respiratory Sounds",
#                     "symbolSize": 13.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "aspartate aminotransferase",
#                     "symbolSize": 17.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "PTB",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "Methotrexate",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": "ADAM15",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "CLTC",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "IFNAR1",
#                     "symbolSize": 16.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "IFITM1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "SRBC",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "Hypotrichosis",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "EDEM1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "IL15",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "DNAJC3",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "FOXP3",
#                     "symbolSize": 13.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "VEGFA",
#                     "symbolSize": 16.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "PENK",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "OAS3",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "Porphyria, South African type",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "autoimmunity",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "IGKV1-16",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "DDX58",
#                     "symbolSize": 23.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "AIM2",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "CEACAM1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "SPARC",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "ITGAM",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "PPP1R15A",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "L2",
#                     "symbolSize": 16.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "MIP1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "MAGT1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "CEBPB",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "C1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "CCL20",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "CDR2",
#                     "symbolSize": 13.0,
#                     "category": 1
#                 },

# %%
# 1. What chemicals have Sa(Side effect/adverse event) to COVID-19 and revelant disease?

# due to a large number of negative words, these predictions may be wrong
c_d_pred_df.loc[c_d_pred_df['pred']=='Sa']
# Out:
#                start_entity                            end_entity  \
# 5               ventilation  Respiratory Distress Syndrome, Adult
# 7                Nelfinavir     Severe Acute Respiratory Syndrome
# 37              ventilation              Corneal Dystrophy, Fleck
# 42              ventilation                              COVID-19
# 44          glucocorticoids                           Lymphopenia
# ..                      ...                                   ...
# 862             ventilation                              COVID-19
# 864  mesenchymal stem cells                                   BMD
# 880         Hexachlorophene           inhibitory concentration 50
# 882             ventilation  Respiratory Distress Syndrome, Adult
# 885  mesenchymal stem cells                     Williams Syndrome
#
#     start_entity_type end_entity_type  \
# 5            Chemical         Disease
# 7            Chemical         Disease
# 37           Chemical         Disease
# 42           Chemical         Disease
# 44           Chemical         Disease
# ..                ...             ...
# 862          Chemical         Disease
# 864          Chemical         Disease
# 880          Chemical         Disease
# 882          Chemical         Disease
# 885          Chemical         Disease
#
#                                        marked_sentence init_pred  \
# 5    Hospital-acquired end_entity may result from a...        Sa
# 7    start_entity inhibited the cytopathic effect i...        Sa
# 37   Findings end_entity simulation revealed that t...        Sa
# 42   The main complications reported in hospitalize...        Sa
# 44   end_entity can be caused by start_entity, and ...        Sa
# ..                                                 ...       ...
# 862  Severe_Acute_Respiratory_Syndrome end_entity d...        Sa
# 864  The injection of Ci-I hydrogels encapsulating ...        Sa
# 880  start_entity end_entity: 6M, tannic acid end_e...        Sa
# 882  Compared with survivors, non-survivors were ol...        Sa
# 885  In this study, we screened a natural product l...        Sa
#
#      init_pred_prob reverse_pred  reverse_pred_prob     filter pred  pred_prob
# 5          0.954767           Sa           0.997769  init_pred   Sa   0.954767
# 7          0.559930            C           0.601428  init_pred   Sa   0.559930
# 37         0.747989           Pr           0.768367  init_pred   Sa   0.747989
# 42         0.976008           Sa           0.957273  init_pred   Sa   0.976008
# 44         0.981520           Pr           0.482006  init_pred   Sa   0.981520
# ..              ...          ...                ...        ...  ...        ...
# 862        0.748148            C           0.995705  init_pred   Sa   0.748148
# 864        0.765685            T           0.818395  init_pred   Sa   0.765685
# 880        0.816925           Pa           0.654468  init_pred   Sa   0.816925
# 882        0.824085            J           0.619180  init_pred   Sa   0.824085
# 885        0.920667           Pr           0.570124  init_pred   Sa   0.920667
#
# [78 rows x 12 columns]

# %%
# 2. What genes have U(Causal mutations), Ud(Mutations affect disease course), Y(Polymorphisms alter risk) to COVID-19?


g_d_pred_df.loc[(g_d_pred_df['end_entity']=='COVID-19')&(g_d_pred_df['pred'].isin(['U','Ud','Y']))]
# Out:
#      start_entity end_entity start_entity_type end_entity_type  \
# 1             p28   COVID-19              Gene         Disease
# 4              E1   COVID-19              Gene         Disease
# 5              E2   COVID-19              Gene         Disease
# 9          ERVW-1   COVID-19              Gene         Disease
# 11             E1   COVID-19              Gene         Disease
# ...           ...        ...               ...             ...
# 7807           S2   COVID-19              Gene         Disease
# 7819         ACE2   COVID-19              Gene         Disease
# 7835         ACE2   COVID-19              Gene         Disease
# 7862        MERTK   COVID-19              Gene         Disease
# 7868        PLpro   COVID-19              Gene         Disease
#
#                                         marked_sentence init_pred  \
# 1     A high level of similarity was detected betwee...        Ud
# 4     The carbohydrate contents of end_entity glycop...         U
# 5     The carbohydrate contents of end_entity glycop...         U
# 9     Tunicamycin has different effects on the glyco...        Ud
# 11    The end_entity envelope ERVW-1 start_entity ap...        Ud
# ...                                                 ...       ...
# 7807  The severe acute respiratory syndrome end_enti...         Y
# 7819  Molecular modeling revealed that end_entity RB...         U
# 7835  Infection by severe acute respiratory syndrome...         U
# 7862  A 12 start_entity peptide derived from end_ent...        Ud
# 7868  Severe_Acute_Respiratory_Syndrome end_entity S...         U
#
#       init_pred_prob reverse_pred  reverse_pred_prob     filter pred  \
# 1           0.932619            U           0.975709  init_pred   Ud
# 4           0.959629            U           0.977800  init_pred    U
# 5           0.935262            J           0.610720  init_pred    U
# 9           0.687813            Y           0.812220  init_pred   Ud
# 11          0.989256            L           0.718454  init_pred   Ud
# ...              ...          ...                ...        ...  ...
# 7807        0.676697            U           0.480305  init_pred    Y
# 7819        0.607003            Y           0.998896  init_pred    U
# 7835        0.928476            U           0.836398  init_pred    U
# 7862        0.558339            J           0.512180  init_pred   Ud
# 7868        0.695125            J           0.999687  init_pred    U
#
#       pred_prob
# 1      0.932619
# 4      0.959629
# 5      0.935262
# 9      0.687813
# 11     0.989256
# ...         ...
# 7807   0.676697
# 7819   0.607003
# 7835   0.928476
# 7862   0.558339
# 7868   0.695125
#
# [547 rows x 12 columns]

# %%
# 3. What diseases are associated to COVID-19 (like complication)?
d_d_df = relation_df.loc[((relation_df['start_entity']=='COVID-19')&(relation_df['end_entity_type']=='Disease'))|((relation_df['start_entity_type']=='Disease')&(relation_df['end_entity']=='COVID-19'))]
value_counts_dic = dict(d_d_df['start_entity'].value_counts())
end_entity_value_counts_dic = dict(d_d_df['end_entity'].value_counts())
for key in end_entity_value_counts_dic:
    if key in value_counts_dic:
        value_counts_dic[key] += end_entity_value_counts_dic[key]
    else:
        value_counts_dic[key] = end_entity_value_counts_dic[key]
most_relevant_disease = []
for key in value_counts_dic:
    if value_counts_dic[key] > 10:
        most_relevant_disease.append(key)
relation_df.loc[((relation_df['start_entity'].isin(most_relevant_disease))&(relation_df['end_entity']=='COVID-19'))|((relation_df['start_entity']=='COVID-19')&(relation_df['end_entity'].isin(most_relevant_disease)))]
# Out:
#       start_entity                         end_entity start_entity_type  \
# 30951     COVID-19  Cataract congenital Volkmann type           Disease
# 30956     COVID-19  Cataract congenital Volkmann type           Disease
# 30961     COVID-19                   Influenza, Human           Disease
# 30964     COVID-19  Cataract congenital Volkmann type           Disease
# 30971     COVID-19                          Infection           Disease
# ...            ...                                ...               ...
# 39569     COVID-19  Severe Acute Respiratory Syndrome           Disease
# 39572     COVID-19             Coronavirus Infections           Disease
# 39573     COVID-19                               MERS           Disease
# 39574     COVID-19  Severe Acute Respiratory Syndrome           Disease
# 39575     COVID-19                           Syndrome           Disease
#
#       end_entity_type                                    marked_sentence pred  \
# 30951         Disease  The pathogenesis of canine start_entity end_en...   DD
# 30956         Disease  The genomic organization at the 3 end of canin...   DD
# 30961         Disease  Blood was taken from the sows at the beginning...   DD
# 30964         Disease  From the reasons that canine start_entity end_...   DD
# 30971         Disease  end_entity of cell monolayers by murine start_...   DD
# ...               ...                                                ...  ...
# 39569         Disease  end_entity start_entity end_entity-CoV papain-...   DD
# 39572         Disease  In a recent review on the persistence of human...   DD
# 39573         Disease  In a recent review on the persistence of human...   DD
# 39574         Disease  In a recent review on the persistence of human...   DD
# 39575         Disease  In a recent review on the persistence of human...   DD
#
#        pred_prob
# 30951        NaN
# 30956        NaN
# 30961        NaN
# 30964        NaN
# 30971        NaN
# ...          ...
# 39569        NaN
# 39572        NaN
# 39573        NaN
# 39574        NaN
# 39575        NaN
#
# [2450 rows x 7 columns]

# %%
# 1. What chemicals have Pa(Alleviates, reduces), Pr(Prevents, suppresses), T(Treatment/therapy (incl. investigatory)) to COVID-19 and revelant disease?

c_d_pred_df.loc[(c_d_pred_df['end_entity']=='COVID-19')&(c_d_pred_df['pred'].isin(['Pa','Pr','T']))]
# Out:
#                start_entity end_entity start_entity_type end_entity_type  \
# 2                Daptomycin   COVID-19          Chemical         Disease
# 15              ventilation   COVID-19          Chemical         Disease
# 47              oseltamivir   COVID-19          Chemical         Disease
# 55              ventilation   COVID-19          Chemical         Disease
# 57              Ganciclovir   COVID-19          Chemical         Disease
# 59              ventilation   COVID-19          Chemical         Disease
# 67              Chloroquine   COVID-19          Chemical         Disease
# 69              ventilation   COVID-19          Chemical         Disease
# 78              ventilation   COVID-19          Chemical         Disease
# 79              ventilation   COVID-19          Chemical         Disease
# 90              ventilation   COVID-19          Chemical         Disease
# 95               remdesivir   COVID-19          Chemical         Disease
# 97          glucocorticoids   COVID-19          Chemical         Disease
# 98              ventilation   COVID-19          Chemical         Disease
# 99              ventilation   COVID-19          Chemical         Disease
# 100              remdesivir   COVID-19          Chemical         Disease
# 102              remdesivir   COVID-19          Chemical         Disease
# 104             Chloroquine   COVID-19          Chemical         Disease
# 105      Hydroxychloroquine   COVID-19          Chemical         Disease
# 106                   PX-12   COVID-19          Chemical         Disease
# 107             ventilation   COVID-19          Chemical         Disease
# 111              remdesivir   COVID-19          Chemical         Disease
# 112    membrane oxygenation   COVID-19          Chemical         Disease
# 116     Lopinavir/Ritonavir   COVID-19          Chemical         Disease
# 120              remdesivir   COVID-19          Chemical         Disease
# 122              remdesivir   COVID-19          Chemical         Disease
# 123         glucocorticoids   COVID-19          Chemical         Disease
# 125         oxygen therapy    COVID-19          Chemical         Disease
# 126             ventilation   COVID-19          Chemical         Disease
# 135             ventilation   COVID-19          Chemical         Disease
# 787              remdesivir   COVID-19          Chemical         Disease
# 794             Oseltamivir   COVID-19          Chemical         Disease
# 799             ventilation   COVID-19          Chemical         Disease
# 804               Vitamin C   COVID-19          Chemical         Disease
# 805             ventilation   COVID-19          Chemical         Disease
# 806             ventilation   COVID-19          Chemical         Disease
# 812             ventilation   COVID-19          Chemical         Disease
# 823             ventilation   COVID-19          Chemical         Disease
# 830              SSYA10-001   COVID-19          Chemical         Disease
# 833             oseltamivir   COVID-19          Chemical         Disease
# 836             oseltamivir   COVID-19          Chemical         Disease
# 857              Amantadine   COVID-19          Chemical         Disease
# 859             ventilation   COVID-19          Chemical         Disease
# 868                    Zinc   COVID-19          Chemical         Disease
# 872              remdesivir   COVID-19          Chemical         Disease
# 875             ventilation   COVID-19          Chemical         Disease
# 876  mesenchymal stem cells   COVID-19          Chemical         Disease
# 887         oxygen therapy    COVID-19          Chemical         Disease
# 888             ventilation   COVID-19          Chemical         Disease
# 889         glucocorticoids   COVID-19          Chemical         Disease
# 890             oseltamivir   COVID-19          Chemical         Disease
#
#                                        marked_sentence init_pred  \
# 2    start_entity is not indicated for end_entity, ...         T
# 15   Study objectives: To report on our experience ...         T
# 47   During the pandemic H1N1 2009 influenza A viru...         T
# 55   Bad housing, particularly bad start_entity, wi...        Pr
# 57   start_entity can be considered for patients wi...         T
# 59   Case report We report a case of acute respirat...         T
# 67   start_entity, remdesivir, lopinavir, ribavirin...         T
# 69   Three clinical cases of patients presenting se...         T
# 78   The populations of patients with community-acq...         T
# 79   By contrast, the use of non-invasive start_ent...         T
# 90   Methods In this retrospective cohort study, we...         T
# 95   Herein, we suggest four potential drug candida...         T
# 97   With more and more patients diagnosed, China h...         T
# 98   Another series10 of nine pregnant women with e...         T
# 99   About 1520 of suspected and confirmed patients...         T
# 100  Gengfu Xiao, Wu Zhong and Zhihong Hu, the anti...         T
# 102  25, the US National Institutes of Health NIH s...         T
# 104  start_entity has been sporadically used in tre...         T
# 105  CONCLUSIONS: start_entity was found to be more...        Pa
# 106  Molecular docking against the two thiol protea...        Pa
# 107  For end_entity patients with mechanical start_...         T
# 111  Drugs are possibly effective for end_entity in...         T
# 112  long with the sharp increase of confirmed case...         T
# 116  Combination of Ribavirin and Interferon- is re...         T
# 120  Several drugs such as chloroquine, arbidol, st...         T
# 122  Recently, the RNA polymerase start_entity had ...         T
# 123  Because of the delayed clearance of viral RNA ...         T
# 125  The treatment experience in severe cases of 20...         T
# 126  The treatment experience in severe cases of 20...        Pr
# 135  CONCLUSIONS: Community-acquired adenovirus end...         T
# 787  We recently reported that the nucleoside analo...        Pa
# 794  Intranasal administration of PA markedly impro...        Pa
# 799  Compared with continuous invasive start_entity...        Pa
# 804  Therefore, we tested a set of Strepsils lozeng...        Pr
# 805  INTRODUCTION: Non-invasive start_entity NIV is...         T
# 806  CONCLUSION: Special attention should be given ...         T
# 812  Twenty-seven articles were grouped into the fo...        Pa
# 823  PURPOSE: To compare the outcomes of patients h...         T
# 830  Here, we show that start_entity also inhibits ...         T
# 833  No start_entity treatment studies reported eff...         T
# 836  Treatment trials with start_entity or zanamivi...        Pa
# 857  However, three drugs approved for human use ma...        Pa
# 859  Conclusions: Room start_entity, open space, pr...        Pa
# 868  Conclusions: start_entity supplementation impr...         T
# 872  The one case of end_entity end_entity in the U...         T
# 875  Middle East respiratory syndrome end_entity ME...         T
# 876  Transplantation of start_entity MSCs is a prom...         T
# 887  Supporting the recommendation of the authors, ...         T
# 888  Supporting the recommendation of the authors, ...        Pa
# 889  8 Fifth, WHO has made it clear that there are ...         T
# 890  Despite this, there have been reports of the u...         T
#
#      init_pred_prob reverse_pred  reverse_pred_prob     filter pred  pred_prob
# 2          0.999757            T           0.597814  init_pred    T   0.999757
# 15         0.999976           Sa           0.998793  init_pred    T   0.999976
# 47         0.584085            T           0.932823  init_pred    T   0.584085
# 55         0.759889           Sa           0.961628  init_pred   Pr   0.759889
# 57         0.999927            T           0.999898  init_pred    T   0.999927
# 59         0.848479           Sa           0.999983  init_pred    T   0.848479
# 67         0.948416           Pr           0.833725  init_pred    T   0.948416
# 69         0.946440            T           0.936319  init_pred    T   0.946440
# 78         0.999792            C           0.627972  init_pred    T   0.999792
# 79         0.998000            T           0.521089  init_pred    T   0.998000
# 90         0.999998            T           0.999974  init_pred    T   0.999998
# 95         0.824200            T           0.988221  init_pred    T   0.824200
# 97         0.977593           Sa           0.791995  init_pred    T   0.977593
# 98         0.999441           Sa           0.931193  init_pred    T   0.999441
# 99         0.998170           Sa           0.994765  init_pred    T   0.998170
# 100        0.753338            T           0.753338  init_pred    T   0.753338
# 102        0.672600           Sa           0.957549  init_pred    T   0.672600
# 104        0.999489            T           0.996359  init_pred    T   0.999489
# 105        0.996757           Pa           0.701929  init_pred   Pa   0.996757
# 106        0.821956            J           0.999817  init_pred   Pa   0.821956
# 107        0.999752            T           0.997911  init_pred    T   0.999752
# 111        0.998933           Pr           0.989575  init_pred    T   0.998933
# 112        0.998529            T           0.999905  init_pred    T   0.998529
# 116        0.999992            T           0.999994  init_pred    T   0.999992
# 120        0.999784           Sa           0.993309  init_pred    T   0.999784
# 122        0.992526           Pa           0.570590  init_pred    T   0.992526
# 123        0.992700            T           0.487108  init_pred    T   0.992700
# 125        0.928401            T           0.948041  init_pred    T   0.928401
# 126        0.913142            T           0.991021  init_pred   Pr   0.913142
# 135        0.999564           Sa           0.999994  init_pred    T   0.999564
# 787        0.999938            C           0.931957  init_pred   Pa   0.999938
# 794        0.999786           Sa           0.983383  init_pred   Pa   0.999786
# 799        0.984846            J           0.951271  init_pred   Pa   0.984846
# 804        0.987307           Pr           0.999992  init_pred   Pr   0.987307
# 805        0.983459            C           0.781648  init_pred    T   0.983459
# 806        0.651055           Sa           0.920125  init_pred    T   0.651055
# 812        0.999425           Pa           0.890724  init_pred   Pa   0.999425
# 823        0.999985            C           0.998503  init_pred    T   0.999985
# 830        0.997491           Sa           0.856665  init_pred    T   0.997491
# 833        0.987213            T           0.867699  init_pred    T   0.987213
# 836        0.722913           Sa           0.997325  init_pred   Pa   0.722913
# 857        0.994300           Sa           0.853908  init_pred   Pa   0.994300
# 859        0.954350           Pr           0.794331  init_pred   Pa   0.954350
# 868        0.948984            T           0.663317  init_pred    T   0.948984
# 872        0.999963            T           0.999805  init_pred    T   0.999963
# 875        0.999833           Sa           0.999952  init_pred    T   0.999833
# 876        0.999805            T           0.855519  init_pred    T   0.999805
# 887        0.940325           Sa           0.989545  init_pred    T   0.940325
# 888        0.943463           Sa           0.998464  init_pred   Pa   0.943463
# 889        0.997896           Pr           0.703676  init_pred    T   0.997896
# 890        0.999295            T           0.758857  init_pred    T   0.999295

# %%
# 2. What genes have D(Drug targets), G(Promotes progression), J(Role in pathogenesis), Te(Possible therapeutic effect), X(Overexpression in disease) to COVID-19 and revelant disease?

g_d_pred_df.loc[(g_d_pred_df['end_entity']=='COVID-19')&(g_d_pred_df['pred'].isin(['D','G','J','Te','X']))]
# Out:
#      start_entity end_entity start_entity_type end_entity_type  \
# 8           GCNT2   COVID-19              Gene         Disease
# 18          PSMD1   COVID-19              Gene         Disease
# 24          CYTIP   COVID-19              Gene         Disease
# 27             S2   COVID-19              Gene         Disease
# 33          CYTIP   COVID-19              Gene         Disease
# ...           ...        ...               ...             ...
# 7805        PSMD1   COVID-19              Gene         Disease
# 7808       NDUFB6   COVID-19              Gene         Disease
# 7810        IFNA1   COVID-19              Gene         Disease
# 7834        ARIH1   COVID-19              Gene         Disease
# 7870         BRD2   COVID-19              Gene         Disease
#
#                                         marked_sentence init_pred  \
# 8     This end_entity, like influenza virus, can rep...         J
# 18    The sequences of the peplomeric start_entity p...         J
# 24    The hemagglutininesterase start_entity, spike ...         D
# 27    These observations may reflect the biological ...        Te
# 33    In contrast to bovine end_entity, which appare...         J
# ...                                                 ...       ...
# 7805  We investigated the kinetics of serologic resp...        Te
# 7808  We fitted a log-normal distribution to pooled ...         D
# 7810  Poxvirus and end_entity mutants that lacked 2-...        Te
# 7834  The Human respiratory syncytial virus RSV is o...        Te
# 7870  Conclusions Therefore, we concluded that viral...        Te
#
#       init_pred_prob reverse_pred  reverse_pred_prob     filter pred  \
# 8           0.999964           Ud           0.578845  init_pred    J
# 18          0.958231            U           0.994972  init_pred    J
# 24          0.480011           Te           0.834435  init_pred    D
# 27          0.731483            J           0.999688  init_pred   Te
# 33          0.993720            L           0.988948  init_pred    J
# ...              ...          ...                ...        ...  ...
# 7805        0.744867            J           0.997138  init_pred   Te
# 7808        0.962257           Te           0.909175  init_pred    D
# 7810        0.784434            J           0.973893  init_pred   Te
# 7834        0.914886            J           0.916927  init_pred   Te
# 7870        0.999843            J           0.969410  init_pred   Te
#
#       pred_prob
# 8      0.999964
# 18     0.958231
# 24     0.480011
# 27     0.731483
# 33     0.993720
# ...         ...
# 7805   0.744867
# 7808   0.962257
# 7810   0.784434
# 7834   0.914886
# 7870   0.999843
#
# [680 rows x 12 columns]
